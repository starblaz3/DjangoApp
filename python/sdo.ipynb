# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# read csv file
df = pd.read_csv('../temp.csv')
print(type(df))
print(df.shape) 
print(df.head(10))
df.plot()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (96, 2)
#    water_temperature(C)   air_temperature(C)
# 0                    26                23.01
# 1                    26                24.87
# 2                    27                27.66
# 3                    26                29.15
# 4                    29                30.48
# 5                    27                28.91
# 6                    26                28.26
# 7                    28                28.31
# 8                    24                28.06
# 9                    27                27.91

# %%
new_df = pd.DataFrame()
new_df['saturated_dissolved_oxygen(mg/L)'] = np.exp(-139.3441 + ((1.575701e5)/(df['water_temperature(C)']+273)) - ((6.642308e7)/(df['water_temperature(C)']+273)**2) + ((1.243800e10)/(df['water_temperature(C)']+273)**3) - ((8.621949e11)/(df['water_temperature(C)']+273)**4))

new_df.index = df.index
print(new_df.head(10))

# export the new_df into saturated_DO.csv
new_df.to_csv('../saturated_DO.csv', index=False)
# Out:
#    saturated_dissolved_oxygen(mg/L)
# 0                          8.135877
# 1                          8.135877
# 2                          7.990044
# 3                          8.135877
# 4                          7.711582
# 5                          7.990044
# 6                          8.135877
# 7                          7.848690
# 8                          8.441975
# 9                          7.990044
